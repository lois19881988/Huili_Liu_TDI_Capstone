# %% [markdown]
# # Huili Liu Capsone Project Weekly Report: Week 2

# %% [markdown]
# ## What is a good movie and what is a bad movie?

# %% [markdown]
# <html>
# <head>
# <style>
# table, th, td, tr{
#     border: 1px solid black;
#     border-collapse: collapse;
# }
# th, td, tr {
#     padding: 5px;
#     text-align: center;
# }
# </style>
# </head>
# <body>
#     <h2><a href="https://www.imdb.com/title/tt0111161/?ref_=nv_sr_1" itemprop="url">The Shawshank Redemption (1994) </a>
#     <br>
#     <br>
#     **IMDB Score**: 9.4
#     </h2>
#
#     <table style="width:100%">
#       <tr>
#         <td rowspan="10">
#             <a href="title/tt0111161/?ref_=nv_sr_1">
#                 <img height="360" width="270" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX182_CR0,0,182,268_AL_.jpg" class="loadlate">
#             </a>
#         </td>
#
#
#           <td>**Budget**: $25,000,000 (estimated)</td>
#
#            <td rowspan="10" align="left">
#               <h4>Plot Summary</h4>
#                 The Shawshank Redemption is a highly-acclaimed movie starring Tim Robbins and Morgan Freeman. Andy Dufresne is convicted of the murder of his wife and her lover, and sentenced to life imprisonment at Shawshank prison. Life seems to have taken a turn for the worse, but fortunately Andy befriends some of the other inmates, in particular a character known only as Red. Over time Andy finds ways to live out life with relative ease as one can in a prison, leaving a message for all that while the body may be locked away in a cell, the spirit can never be truly imprisoned.
#             </td>
#
#       </tr>
#       <tr>
#           <td>**Gross USA**: $28,341,469 (estimated)</td>
#       </tr>
#
#       <tr>
#           <td>**Gross Worldwide**: $58,500,000 (estimated)</td>
#       </tr>
#
#       <tr>
#           <td>**Certificate**: R</td>
#       </tr>
#
#       <tr>
#           <td>**Runtime**: 142 min</td>
#       </tr>
#
#       <tr>
#           <td>**Release Date USA**: 14 October 1994 (USA)</td>
#       </tr>
#
#       <tr>
#           <td>**Genres**: Drama</td>
#       </tr>
#
#       <tr>
#           <td>**Director(s)**: Frank Darabont</td>
#       </tr>
#
#       <tr>
#           <td>**Writer(s)**: Stephen King, Frank Darabont</td>
#       </tr>
#
#       <tr>
#           <td>**Star(s)**: Tim Robbins, Morgan Freeman, Bob Gunton</td>
#
#         </td>
#
#       </tr>
#
#     </table>
#
# </body>
# </html>

# %% [markdown]
# <html>
# <head>
# <style>
# table, th, td, tr{
#     border: 1px solid black;
#     border-collapse: collapse;
# }
# th, td, tr {
#     padding: 5px;
#     text-align: center;
# }
# </style>
# </head>
# <body>
#     <h2><a href="https://www.imdb.com/title/tt0368226/?ref_=fn_al_tt_1" itemprop="url">The Room (2003)</a>
#         <br>
#         **IMDB Score**: 3.6
#     </h2>
#
#     <table style="width:100%">
#       <tr>
#         <th rowspan="10">
#             <a href="title/tt0368226/?ref_=fn_al_tt_1">
#                 <img height="360" width="270" src="https://m.media-amazon.com/images/M/MV5BMTg4MTU1MzgwOV5BMl5BanBnXkFtZTcwNjM1MTAwMQ@@._V1_UY268_CR12,0,182,268_AL_.jpg" class="loadlate">
#             </a>
#         </th>
#           <td>**Budget**: $6,000,000 (estimated)</td>
#           <td rowspan="10" align="left">
#               <h4>Plot Summary</h4>
# Johnny is a successful banker who lives happily in a San Francisco townhouse with his fiancée, Lisa. One day, inexplicably, she gets bored with him and decides to seduce his best friend, Mark. From there, nothing will be the same again.
#           </td>
#
#       </tr>
#       <tr>
#           <td>**Gross USA**: NA</td>
#       </tr>
#
#       <tr>
#           <td>**Gross Worldwide**: NA</td>
#       </tr>
#
#       <tr>
#           <td>**Certificate**: R</td>
#       </tr>
#
#       <tr>
#           <td>**Runtime**: 99 min</td>
#       </tr>
#
#       <tr>
#           <td>**Release Date USA**: 3 March 2004 (USA)</td>
#       </tr>
#
#       <tr>
#           <td>**Genres**: Drama</td>
#       </tr>
#
#       <tr>
#           <td>**Director(s)**: Tommy Wiseau</td>
#       </tr>
#
#       <tr>
#           <td>**Writer(s)**:  Tommy Wiseau</td>
#       </tr>
#
#       <tr>
#           <td>**Star(s)**: Tommy Wiseau, Juliette Danielle, Greg Sestero</td>
#       </tr>
#
#     </table>
#
# </body>
# </html>

# %% [markdown]
# ## What are the features accociated with good movies?
#
# <br>
# <font size=4>1. How do the posters of successful movies look like?
# <font size=3>* Are they brighter or darker? Or should they have the expected brightness according to their specific genre?
# <font size=3>* Should they have more contrast?
# <font size=3>* What else?
# <br>
# <font size=4>2. What are the key words in the plot summary of successful movies?
# <br>
# <font size=4>3. When is a good month for a movie premiere?
# <br>
# <font size=4>4. How long should a successful movie be?
# <br>
# <font size=4>5. Do the results for these questions remain consistent over years and across movie genres?

# %% [markdown]
# ## Data source to predict IMDB ratings
# * **Scrape data for 9,953 U.S released movies from 1971 to 2016 from IMDB**<br>
# * **Download posters for all movies and use image processing procedure to extract information, such as poster bightness, whether the poster has human faces, poster contrast, etc**<br>
# * **Find the common words in each movie's plot summary and correlate those words with movie success and movie genre**<br>
# * **Controlling for other features such as release month, MPAA film rating, movie length, etc.**<br>

# %% [markdown]
# ## Some previews

# %% [markdown]
# ![title](Q3_plot1.jpeg)

# %% [markdown]
# ![title](overall.png)`
